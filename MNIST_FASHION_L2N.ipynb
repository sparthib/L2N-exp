# %%
import keras
import tensorflow as tf
import sklearn
import scipy
import numpy as np
import joblib

# %%
pip install --user C:\Users\Sowmya\Documents\Github\proglearn
# Out:
# Processing c:\users\sowmya\documents\github\proglearn
# Requirement already satisfied: keras>=2.3.1 in c:\users\sowmya\anaconda3\lib\site-packages (from proglearn==0.0.3) (2.4.3)
# Requirement already satisfied: tensorflow>=1.19.0 in c:\users\sowmya\anaconda3\lib\site-packages (from proglearn==0.0.3) (2.4.1)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\sowmya\anaconda3\lib\site-packages (from proglearn==0.0.3) (0.23.2)
# Requirement already satisfied: scipy==1.4.1 in c:\users\sowmya\anaconda3\lib\site-packages (from proglearn==0.0.3) (1.4.1)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\sowmya\anaconda3\lib\site-packages (from proglearn==0.0.3) (0.17.0)
# Requirement already satisfied: pyyaml in c:\users\sowmya\anaconda3\lib\site-packages (from keras>=2.3.1->proglearn==0.0.3) (5.3.1)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\sowmya\anaconda3\lib\site-packages (from keras>=2.3.1->proglearn==0.0.3) (1.19.2)
# Requirement already satisfied: h5py in c:\users\sowmya\anaconda3\lib\site-packages (from keras>=2.3.1->proglearn==0.0.3) (2.10.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\sowmya\anaconda3\lib\site-packages (from tensorflow>=1.19.0->proglearn==0.0.3) (3.14.0)
# Requirement already satisfied: grpcio~=1.32.0 in c:\users\sowmya\anaconda3\lib\site-packages (from tensorflow>=1.19.0->proglearn==0.0.3) (1.32.0)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\sowmya\anaconda3\lib\site-packages (from tensorflow>=1.19.0->proglearn==0.0.3) (1.12.1)
# Requirement already satisfied: gast==0.3.3 in c:\users\sowmya\anaconda3\lib\site-packages (from tensorflow>=1.19.0->proglearn==0.0.3) (0.3.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\sowmya\anaconda3\lib\site-packages (from tensorflow>=1.19.0->proglearn==0.0.3) (3.3.0)
# Requirement already satisfied: six~=1.15.0 in c:\users\sowmya\anaconda3\lib\site-packages (from tensorflow>=1.19.0->proglearn==0.0.3) (1.15.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\sowmya\anaconda3\lib\site-packages (from tensorflow>=1.19.0->proglearn==0.0.3) (1.1.2)
# Requirement already satisfied: absl-py~=0.10 in c:\users\sowmya\anaconda3\lib\site-packages (from tensorflow>=1.19.0->proglearn==0.0.3) (0.11.0)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\sowmya\anaconda3\lib\site-packages (from tensorflow>=1.19.0->proglearn==0.0.3) (1.6.3)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\sowmya\anaconda3\lib\site-packages (from tensorflow>=1.19.0->proglearn==0.0.3) (1.12)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\sowmya\anaconda3\lib\site-packages (from tensorflow>=1.19.0->proglearn==0.0.3) (3.7.4.3)
# Requirement already satisfied: tensorboard~=2.4 in c:\users\sowmya\anaconda3\lib\site-packages (from tensorflow>=1.19.0->proglearn==0.0.3) (2.4.1)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in c:\users\sowmya\anaconda3\lib\site-packages (from tensorflow>=1.19.0->proglearn==0.0.3) (2.4.0)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\sowmya\anaconda3\lib\site-packages (from tensorflow>=1.19.0->proglearn==0.0.3) (0.2.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\sowmya\anaconda3\lib\site-packages (from tensorflow>=1.19.0->proglearn==0.0.3) (1.1.0)
# Requirement already satisfied: wheel~=0.35 in c:\users\sowmya\anaconda3\lib\site-packages (from tensorflow>=1.19.0->proglearn==0.0.3) (0.35.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sowmya\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->proglearn==0.0.3) (2.1.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\sowmya\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow>=1.19.0->proglearn==0.0.3) (50.3.1.post20201107)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\sowmya\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow>=1.19.0->proglearn==0.0.3) (1.24.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\sowmya\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow>=1.19.0->proglearn==0.0.3) (0.4.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sowmya\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow>=1.19.0->proglearn==0.0.3) (3.3.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sowmya\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow>=1.19.0->proglearn==0.0.3) (2.24.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\sowmya\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow>=1.19.0->proglearn==0.0.3) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\sowmya\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow>=1.19.0->proglearn==0.0.3) (1.0.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\sowmya\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=1.19.0->proglearn==0.0.3) (4.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\users\sowmya\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=1.19.0->proglearn==0.0.3) (4.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sowmya\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=1.19.0->proglearn==0.0.3) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\sowmya\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=1.19.0->proglearn==0.0.3) (1.3.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\sowmya\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow>=1.19.0->proglearn==0.0.3) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\sowmya\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow>=1.19.0->proglearn==0.0.3) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sowmya\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow>=1.19.0->proglearn==0.0.3) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\sowmya\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow>=1.19.0->proglearn==0.0.3) (2.10)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\sowmya\anaconda3\lib\site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=1.19.0->proglearn==0.0.3) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sowmya\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=1.19.0->proglearn==0.0.3) (3.1.0)
# Building wheels for collected packages: proglearn
#   Building wheel for proglearn (setup.py): started
#   Building wheel for proglearn (setup.py): finished with status 'done'
#   Created wheel for proglearn: filename=proglearn-0.0.3-py3-none-any.whl size=31782 sha256=c6104b38250ef642fa8ee2f376aafc39f37c5e0cb5fa1e8057f9230853ef9dbc
#   Stored in directory: C:\Users\Sowmya\AppData\Local\Temp\pip-ephem-wheel-cache-imzn5zl6\wheels\24\d4\5d\3696f055a72255868caa3da5279f6fc9be6994d4d4324f9524
# Successfully built proglearn
# Installing collected packages: proglearn
#   Attempting uninstall: proglearn
#     Found existing installation: proglearn 0.0.3
#     Uninstalling proglearn-0.0.3:
#       Successfully uninstalled proglearn-0.0.3
# Successfully installed proglearn-0.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import os 
#if you want to know current working dir

os.chdir(r'C:\Users\Sowmya\Documents\Github\proglearn\docs\tutorials\functions')
# if you want to list dir
#os.listdir()

import fte_bte_mnist_functions as fn

# %%
(MNIST_x_train, MNIST_y_train), (MNIST_x_test, MNIST_y_test) = keras.datasets.mnist.load_data()

MNIST_x_data = np.concatenate((MNIST_x_train, MNIST_x_test))
MNIST_y_data = np.concatenate((MNIST_y_train, MNIST_y_test))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step

# %%
(FASHION_x_train, FASHION_y_train), (FASHION_x_test, FASHION_y_test) = keras.datasets.fashion_mnist.load_data()

FASHION_x_data = np.concatenate((FASHION_x_train, FASHION_x_test))
FASHION_y_data = np.concatenate((FASHION_y_train, FASHION_y_test))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 2us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 6s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 2s 0us/step

# %%
### MAIN HYPERPARAMS ###
model = "dnn"
num_tasks = 5
#num_trees = 10
num_points_per_task=500
reps = 100
########################

# %%
accuracy_all_task = fn.run_experiment(MNIST_x_data, MNIST_y_data, num_tasks, num_points_per_task)

# %%
acc, bte, fte, te = fn.calculate_results(accuracy_all_task, num_tasks)
fn.plot_results(acc, bte, fte, te)

# %%
accuracy_all_task = fn.run_experiment(FASHION_x_data, FASHION_y_data, num_tasks, num_points_per_task)

# %%
acc, bte, fte, te = fn.calculate_results(accuracy_all_task, num_tasks)
fn.plot_results(acc, bte, fte, te)

# %%
#MNIST AND FMNIST

# %%
x_data = np.concatenate((FASHION_x_data, MNIST_x_data))
y_data = np.concatenate((FASHION_y_data, MNIST_y_data + 10))

# %%
accuracy_all_task = fn.run_experiment(x_data, y_data, num_tasks, num_points_per_task)

# %%
acc, bte, fte, te = fn.calculate_results(accuracy_all_task, num_tasks)
fn.plot_results(acc, bte, fte, te)
